# %% [markdown]
# # Text Generation
# Introduction
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.
# Select Text to Imitate
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                                     transcript
# Deepak Ravishankar Ramkumar  Right up your alley macha.. u can convince int...
# Karthik Kottiswaran          Watha unga kozha adi sandaila yen thaliya aruk...
# Karthikeyan Narayanaswami    do you really have that much money? 50% un per...
# Krishna Kumar                @919840648198 unga english lam padichu meaning...
# Raj Kumar                    This happens. There are companies that don't e...
# Raj Kumar S                  U wont be in trouble U r the trouble ‎GIF omit...
# Ram                          ‎sticker omitted I saw something like yesterda...
# Ram Balaji Subbaiyan         ‎image omitted 🤷🏻‍♂ Enoda maximum eh 1 yr 10mo...
# Riyas Khan                   ‎sticker omitted ‎sticker omitted Yaaru master...
# Selva Vignesh                Wat 😏😏 Na yenne pannen Even I remember this Pa...

# %%
# Extract only Ali Wong's text
ram_text = data.transcript.loc['Ram']
ram_text[:200]
# Out:
# '\u200esticker omitted I saw something like yesterday. A JD said 12 years of experience in kubernetes where Kubernetes originally introduced less than 10 years ago only 😂 \u200eimage omitted 😂 Guys, i ve changed'

# %% [markdown]
# ## Build a Markov Chain Function
# We are going to build a simple Markov chain function that creates a dictionary:
# The keys should be all of the words in thecorpus
# The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ram_dict = markov_chain(ram_text)
ram_dict
# Out:
# {'\u200esticker': ['omitted', 'omitted'],
#  'omitted': ['I', '😂', 'Same', 'Hahaha', 'what', 'Mac', 'Dai'],
#  'I': ['saw',
#   'recently',
#   'dont',
#   'concur.',
#   'told',
#   'don’t',
#   'prolly',
#   'think.',
#   'do',
#   '?',
#   'don’t',
#   'was',
#   'saw',
#   'like',
#   'was',
#   'think',
#   'must',
#   'can',
#   'no',
#   've',
#   'made',
#   'm',
#   'think',
#   'can',
#   'think',
#   'dont',
#   'am',
#   'have',
#   'bet',
#   'agree',
#   'heard',
#   'found',
#   'don’t'],
#  'saw': ['something', 'her,'],
#  'something': ['like', 'works', 'will', 'gross'],
#  'like': ['yesterday.', 'why', 'i', 'amazon.', 'a', 'an', 'she’s', 'pretty'],
#  'yesterday.': ['A'],
#  'A': ['JD'],
#  'JD': ['said'],
#  'said': ['12'],
#  '12': ['years'],
#  'years': ['of', 'ago', 'da.', 'sleeping'],
#  'of': ['experience',
#   'amends',
#   'companies',
#   'your',
#   'the',
#   'me.',
#   'me.',
#   'us',
#   '@919789987036',
#   'photos',
#   'macro',
#   'pretence.',
#   'your',
#   'you'],
#  'experience': ['in', 'history', 'truly', 'with'],
#  'in': ['kubernetes',
#   'the',
#   'my',
#   'my',
#   'peace,',
#   'the',
#   'the',
#   'the',
#   'church',
#   'recent',
#   'mac',
#   'many',
#   'the',
#   'my',
#   'our',
#   'between.',
#   'terms',
#   'terms',
#   '“palasu”'],
#  'kubernetes': ['where'],
#  'where': ['Kubernetes', 'can'],
#  'Kubernetes': ['originally'],
#  'originally': ['introduced'],
#  'introduced': ['less'],
#  'less': ['than'],
#  'than': ['10', 'what', 'others.'],
#  '10': ['years'],
#  'ago': ['only'],
#  'only': ['😂', 'she', 'here.', 'slightly', 'on'],
#  '😂': ['\u200eimage',
#   'Guys,',
#   'We',
#   'Today',
#   'Neha.',
#   'Had',
#   'True',
#   'Look',
#   'It’s',
#   'can’t',
#   'We'],
#  '\u200eimage': ['omitted', 'omitted', 'omitted', 'omitted', 'omitted'],
#  'Guys,': ['i'],
#  'i': ['ve',
#   'served',
#   'dont',
#   'have',
#   'will',
#   'remove,',
#   'din',
#   've',
#   've',
#   'checked',
#   'still',
#   'get.',
#   'm',
#   'want',
#   'knock',
#   'made',
#   'had',
#   'mean',
#   'learn',
#   've',
#   'm',
#   'take',
#   'dont',
#   '&'],
#  've': ['changed',
#   'served',
#   'managed',
#   'something',
#   'become',
#   'a',
#   '@919946628663'],
#  'changed': ['my', 'because'],
#  'my': ['work',
#   'profile,',
#   'cv',
#   'resume',
#   'fault',
#   'ignorance.',
#   'career',
#   'best.',
#   'past.',
#   'son.',
#   'thing.',
#   'arse',
#   'mac',
#   'phone',
#   'name.',
#   'view.',
#   'photographic'],
#  'work': ['experience', 'from', 'for', 'for'],
#  'history': ['(HCL,'],
#  '(HCL,': ['L&T)'],
#  'L&T)': ['into'],
#  'into': ['One', 'trouble', 'bed'],
#  'One': ['company'],
#  'company': ['---', 'has'],
#  '---': ['Contractor'],
#  'Contractor': ['Software'],
#  'Software': ['Engineer'],
#  'Engineer': ['at'],
#  'at': ['Cisco.',
#   'Cisco,',
#   'your',
#   'cisco',
#   'amazon',
#   'her',
#   'least',
#   'first',
#   'one',
#   'a',
#   'pretence',
#   'her',
#   'me.',
#   'the',
#   'his',
#   "Selva's"],
#  'Cisco.': ['To'],
#  'To': ['avoid'],
#  'avoid': ['questions', 'embarrassment'],
#  'questions': ['like', 'then.'],
#  'why': ['do', '?', 'don’t', 'other'],
#  'do': ['you', 'you', 'right?', 'dude.', 'you', 'it', 'anything'],
#  'you': ['switch',
#   'may',
#   'find',
#   'resonate',
#   've',
#   'identified',
#   'mean',
#   'know',
#   'muppet',
#   'the',
#   'get',
#   'were',
#   'on',
#   'bruh',
#   'tied',
#   'had',
#   'chortled',
#   'Merely',
#   'guys',
#   'lock',
#   'mean.',
#   'Invite',
#   'get',
#   'know',
#   'dithering',
#   'dont',
#   'troll',
#   've',
#   'take',
#   '🤣🤣🤣🤣🤣',
#   'all',
#   'folks.',
#   'all.'],
#  'switch': ['frequently', 'as'],
#  'frequently': ['blah'],
#  'blah': ['blah.'],
#  'blah.': ['I'],
#  'recently': ['figured'],
#  'figured': ['that'],
#  'that': ['recruiters',
#   'rejection',
#   'from',
#   'i',
#   'down',
#   'sort.',
#   'you',
#   'he',
#   'you’re',
#   '@919789987036'],
#  'recruiters': ['reject'],
#  'reject': ['profiles'],
#  'profiles': ['which'],
#  'which': ['have'],
#  'have': ['2', 'seen', 'raised', 'watched', 'improved.'],
#  '2': ['or', 'years'],
#  'or': ['more', 'me'],
#  'more': ['job', 'than'],
#  'job': ['change', 'change', '@919789987036'],
#  'change': ['in', 'history.', 'on'],
#  'the': ['last',
#   'change',
#   'right',
#   'luck',
#   'candidate',
#   'role',
#   'actual',
#   'roles,',
#   'interviews',
#   'mess',
#   'employee',
#   'child.',
#   'news',
#   'date',
#   'last',
#   'subject.',
#   'tone',
#   'past.',
#   'facts.',
#   'doubts',
#   'reason',
#   'youngest',
#   'list.',
#   'past',
#   'starting',
#   'playboy',
#   'options',
#   'lazy',
#   'bed.',
#   'Masturbation',
#   'mooda',
#   'playboy:',
#   'Kalaikum',
#   'best',
#   'idea',
#   '1st',
#   'best',
#   'best',
#   'pose.',
#   'number',
#   'time.',
#   'message.',
#   'sack.'],
#  'last': ['3', 'bench.'],
#  '3': ['years.', 'are', 'of'],
#  'years.': ['Personally'],
#  'Personally': ['seen'],
#  'seen': ['that', 'HR'],
#  'rejection': ['for', 'with'],
#  'for': ['a',
#   'cisco.',
#   '2',
#   'these',
#   'justification,',
#   'the',
#   'the',
#   'the',
#   'do',
#   'some',
#   'the',
#   'me',
#   '@919604854613',
#   'me.',
#   '5th',
#   'iTunes',
#   'so',
#   'an',
#   'shanthini.'],
#  'a': ['guy',
#   'pure',
#   'big',
#   'surprise.',
#   'time.',
#   'hint.',
#   'tissue',
#   'kya,',
#   'disaster.',
#   'kid',
#   'passcode,',
#   'lighter',
#   'pirated',
#   'copy,',
#   'compliment.',
#   'doubt.',
#   'lot,',
#   'forced',
#   'good'],
#  'guy': ['afore'],
#  'afore': ['amazon'],
#  'amazon': ['interview.', '/'],
#  'interview.': ['HR'],
#  'HR': ['rejected', 'rejections'],
#  'rejected': ['pointing'],
#  'pointing': ['frequent'],
#  'frequent': ['switch'],
#  'as': ['reason.', 'a', 'far', 'I'],
#  'reason.': ['But', 'What'],
#  'But': ['im', 'she’s'],
#  'im': ['apprehensive'],
#  'apprehensive': ['if'],
#  'if': ['this', 'you'],
#  'this': ['will',
#   'make',
#   'information.',
#   'da.',
#   'is',
#   'now.',
#   'to',
#   'message.',
#   'peace',
#   'photo',
#   'as'],
#  'will': ['backfire',
#   'appear',
#   'the',
#   'claim',
#   'revert',
#   'pound',
#   'come',
#   'push',
#   'heal'],
#  'backfire': ['on'],
#  'on': ['my',
#   'freq',
#   'my',
#   'that',
#   'heartbroken',
#   '@919789987036',
#   'dope',
#   'Neha,',
#   'a',
#   'same',
#   'iPhone,',
#   'par',
#   'iPhones.'],
#  'profile,': ['it'],
#  'it': ['will',
#   'clicked',
#   'wasn’t',
#   'dude.',
#   '🙏🏼',
#   'felt',
#   'when',
#   'aloud.',
#   'on',
#   'da.',
#   'yours.',
#   'better',
#   'pangu',
#   '?'],
#  'appear': ['like'],
#  'served': ['at', 'at'],
#  'Cisco,': ['Accenture.'],
#  'Accenture.': ['Reality'],
#  'Reality': ['is'],
#  'is': ['different.',
#   'this',
#   'different',
#   'R&D.',
#   'June',
#   '40th',
#   'crumbling.',
#   'the',
#   'for',
#   'typing...',
#   'typing...',
#   'typing...',
#   '@919946628663',
#   'different',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'psycho:',
#   'the',
#   'the',
#   'the',
#   'very',
#   'the',
#   'the',
#   'doing',
#   'only',
#   'not',
#   'a',
#   'single.',
#   'not',
#   'actually'],
#  'different.': ['Hmmm'],
#  'Hmmm': ['i', 'i', 'Fuck', '\u200eimage'],
#  'dont': ['know', 'even', 'get', 'get', 'think', 'know'],
#  'know': ['you', 'more', 'the', 'his', 'why', 'what'],
#  'may': ['be'],
#  'be': ['an',
#   'true,',
#   'in',
#   'now',
#   'much',
#   'paranormal',
#   'preparing',
#   'the',
#   'thinking.'],
#  'an': ['exception', 'easy', 'whore.', 'order', 'iPhone'],
#  'exception': ['da.'],
#  'da.': ['i',
#   'Right,',
#   'half-truth.',
#   'i',
#   'told',
#   '12th',
#   'Then',
#   'If',
#   'Fuck',
#   'At',
#   'Embarrassing',
#   '😆',
#   'Who',
#   'It’s'],
#  'rejections': ['based'],
#  'based': ['on'],
#  'freq': ['job'],
#  'history.': ['Din'],
#  'Din': ['expect', 'happen,'],
#  'expect': ['that'],
#  'from': ['companies', 'cisco', 'HCL', 'my', '@919604854613'],
#  'companies': ['like', 'dont', 'is'],
#  'amazon.': ['My'],
#  'My': ['question'],
#  'question': ['-', 'da.'],
#  '-': ['will', 'thats', 'yes.', 'yes.'],
#  'cv': ['put'],
#  'put': ['me'],
#  'me': ['into', 'at', '&', 'read', 'used', 'back', 'a'],
#  'trouble': ['?'],
#  '?': ['Please',
#   'actually',
#   'wait',
#   '🤣',
#   'I',
#   'Set',
#   'Good',
#   'we',
#   'He',
#   'Just',
#   'I',
#   '👏🏼'],
#  'Please': ['@919663655116'],
#  '@919663655116': ['come', 'is', "He's", 'is'],
#  'come': ['on.', 'and'],
#  'on.': ['Also,', '😂'],
#  'Also,': ['did'],
#  'did': ['you', 'these', 'I', 'you'],
#  'find': ['the', 'the'],
#  'right': ['candidate', 'hand.', 'next'],
#  'candidate': ['at', 'for', 'for'],
#  'your': ['recent',
#   'statement',
#   'pun',
#   'wife.',
#   'wife',
#   'phone',
#   'home.',
#   'name',
#   'Rambavi',
#   'nuptial'],
#  'recent': ['hiring', 'times.'],
#  'hiring': ['process'],
#  'process': ['\u200eimage'],
#  'Same': ['in'],
#  'resume': ['da.'],
#  'Right,': ['i'],
#  'claim': ['ive'],
#  'ive': ['been', 'to'],
#  'been': ['deployed', 'a', 'sprayed'],
#  'deployed': ['to'],
#  'to': ['work',
#   'L&T.',
#   'create',
#   'stomach',
#   'work',
#   'experience',
#   'wake',
#   'be',
#   'Raj.',
#   'make',
#   'your',
#   'you',
#   'get',
#   'hear',
#   'your',
#   'be',
#   'read',
#   'read',
#   'your'],
#  'cisco': ['office,', 'office'],
#  'office,': ['and'],
#  'and': ['payroll',
#   'this',
#   'get',
#   'endorse',
#   'this',
#   'got',
#   'erase..',
#   'erase..',
#   'all',
#   'shot',
#   'that’s'],
#  'payroll': ['company'],
#  'has': ['changed', 'happened'],
#  'because': ['project'],
#  'project': ['was'],
#  'was': ['moved', 'by', 'at', 'heartbroken', 'the', 'too', 'right', 'always'],
#  'moved': ['from'],
#  'HCL': ['to'],
#  'L&T.': ['its'],
#  'its': ['not', 'fraud.', 'this.', 'enforced.'],
#  'not': ['my', 'a', 'a', 'Krishna.', 'creepy', 'my', 'on', 'busy'],
#  'fault': ['etcetera.'],
#  'etcetera.': ['Does'],
#  'Does': ['this'],
#  'make': ['sense', 'peace'],
#  'sense': ['If', 'yet.'],
#  'If': ['i', 'that’s'],
#  'remove,': ['its'],
#  'fraud.': ['i'],
#  'din': ['work', 'ask'],
#  'cisco.': ['why'],
#  'actually': ['i', 'telling'],
#  'office': ['for'],
#  'half-truth.': ['How'],
#  'How': ['can', 'did', 'can'],
#  'can': ['they',
#   'i',
#   'accept',
#   'take',
#   'stop',
#   'move',
#   'practice',
#   'share',
#   'do',
#   'evaluate',
#   'you'],
#  'they': ['verify'],
#  'verify': ['this'],
#  'information.': ['Hmmm.'],
#  'Hmmm.': ['what'],
#  'what': ['would', 'do', 'nonsense', 'i', 'i', 'are', 'would'],
#  'would': ['you', 'agree.', 'agree', 'he'],
#  'resonate': ['for'],
#  'these': ['questions', 'things', 'Macha.'],
#  'then.': ['product'],
#  'product': ['companies'],
#  'even': ['ask', 'talk'],
#  'ask': ['for', 'us', 'the', 'this'],
#  'justification,': ['rejection'],
#  'with': ['reason,',
#   'folks',
#   'high',
#   'that.',
#   'fire,',
#   'Deepak.',
#   'semen',
#   'church',
#   'my'],
#  'reason,': ['no'],
#  'no': ['looking', 'longer'],
#  'looking': ['back.', 'back.'],
#  'back.': ['Hmmm', 'This'],
#  'managed': ['until'],
#  'until': ['now.', 'i'],
#  'now.': ['ive', 'Talk'],
#  'create': ['new'],
#  'new': ['stories'],
#  'stories': ['again.'],
#  'again.': ['share'],
#  'share': ['if',
#   'https://m.economictimes.com/news/politics-and-nation/muslim-refugees-become-christians-to-take-caa-benefit/articleshow/77117484.cms'],
#  'works': ['well'],
#  'well': ['Mhmmm'],
#  'Mhmmm': ['Ok'],
#  'Ok': ['will', 'cool.', 'gonna'],
#  'revert': ['these.'],
#  'these.': ['Glad'],
#  'Glad': ['that'],
#  'checked': ['with'],
#  'folks': ['here.'],
#  'here.': ['Hmmm', 'I’m'],
#  'Fuck': ['the', 'I'],
#  'luck': ['🙄'],
#  '🙄': ['Have'],
#  'Have': ['you', 'to'],
#  'identified': ['the'],
#  'role': ['Macha'],
#  'Macha': ['pardon', '😏'],
#  'pardon': ['my'],
#  'ignorance.': ['I'],
#  'get': ['the', 'experience', 'married.', 'involved.', 'involved', 'it.'],
#  'actual': ['context.'],
#  'context.': ['what'],
#  'mean': ['by', 'not'],
#  'by': ["'be", 'December', 'some', 'Karthik', 'MEEEEEEEEEEE,'],
#  "'be": ["ready'"],
#  "ready'": ['preparation,'],
#  'preparation,': ['applying'],
#  'applying': ['for'],
#  'roles,': ['appearing'],
#  'appearing': ['for'],
#  'interviews': ['-'],
#  'thats': ['all'],
#  'all': ['any', 'i', 'together.', '4', 'these', '😂😂😂', 'the', 'the'],
#  'any': ['candidate', 'chance,'],
#  'right?': ['what'],
#  'nonsense': ['is'],
#  'still': ['cant', 'at'],
#  'cant': ['able', 'stand'],
#  'able': ['to'],
#  'stomach': ['this.'],
#  'this.': ['ohh.', 'whats'],
#  'ohh.': ['lets'],
#  'lets': ['see'],
#  'see': ['what'],
#  'get.': ['i'],
#  'm': ['waiting', 'not', 'texting'],
#  'waiting': ['I'],
#  'concur.': ['Just'],
#  'Just': ['whining', 'the'],
#  'whining': ['👌🏼'],
#  '👌🏼': ['yeah'],
#  'yeah': ['macha.'],
#  'macha.': ['i', 'and'],
#  'want': ['to', 'to'],
#  'some': ['top', 'reason.'],
#  'top': ['tier'],
#  'tier': ['companies.'],
#  'companies.': ['will'],
#  'pound': ['until'],
#  'knock': ['that'],
#  'down': ['also,', 'in', 'He'],
#  'also,': ['sort'],
#  'sort': ['of', 'of'],
#  'amends': ['for'],
#  'mess': ['i'],
#  'made': ['so', 'it'],
#  'so': ['far', 'far', 'long..'],
#  'far': ['in', 'all', 'as'],
#  'career': ['fidelity'],
#  'fidelity': ['da.'],
#  'told': ['you.', 'you'],
#  'you.': ['to'],
#  'truly': ['enterprise', 'belongs'],
#  'enterprise': ['deliverables,'],
#  'deliverables,': ['distributed'],
#  'distributed': ['scalable'],
#  'scalable': ['projects.'],
#  'projects.': ['so', 'where'],
#  'had': ['chances', 'delivered', 'her'],
#  'chances': ['are'],
#  'are': ['small', 'you', 'single.', 'you', 'equal', 'there.', 'shot'],
#  'small': ['scale.'],
#  'scale.': ['max'],
#  'max': ['upto'],
#  'upto': ['500'],
#  '500': ['users.'],
#  'users.': ['Also'],
#  'Also': ['the'],
#  'employee': ['benefits,'],
#  'benefits,': ['pay,'],
#  'pay,': ['brand.'],
#  'brand.': ['working'],
#  'working': ['at'],
#  '/': ['twitter', 'facebook', 'sort'],
#  'twitter': ['/'],
#  'facebook': ['/'],
#  'different': ['thing', 'in'],
#  'thing': ['all', 'at', '@919663655116'],
#  'together.': ['you'],
#  'pure': ['software'],
#  'software': ['firm'],
#  'firm': ['macha.'],
#  'R&D.': ['mostly'],
#  'mostly': ['POC'],
#  'POC': ['projects.'],
#  'learn': ['and'],
#  'high': ['scale'],
#  'scale': ['systems.'],
#  'systems.': ['ofcourse.'],
#  'ofcourse.': ['anything'],
#  'anything': ['on', 'Pipe'],
#  'sort.': ['concur'],
#  'concur': ['with'],
#  'that.': ['team', 'P'],
#  'team': ['-'],
#  'yes.': ['shut', 'Raj'],
#  'shut': ['up', 'down,'],
#  'up': ['you', 'riyas', 'a'],
#  'muppet': ['Not'],
#  'Not': ['true.', 'my', 'you'],
#  'true.': ['Completely'],
#  'Completely': ['untrue.'],
#  'untrue.': ['38th'],
#  '38th': ['week'],
#  'week': ['only', 'No', 'was'],
#  'she': ['had', 'was'],
#  'delivered': ['the'],
#  'child.': ['Expected'],
#  'Expected': ['delivery'],
#  'delivery': ['date'],
#  'date': ['is', 'calculations'],
#  'June': ['6.'],
#  '6.': ['Which'],
#  'Which': ['is'],
#  '40th': ['week'],
#  'No': ['da.', 'worries', 'spin', 'No.'],
#  '12th': ['week'],
#  'December': ['only.'],
#  'only.': ['I'],
#  'news': ['when'],
#  'when': ['she', 'you'],
#  'her': ['6th', 'father', 'like', 'mug.'],
#  '6th': ['week.'],
#  'week.': ['That’s', 'You'],
#  'That’s': ['October'],
#  'October': ['2nd'],
#  '2nd': ['week.'],
#  'You': ['totally', 'missed', 'both'],
#  'totally': ['forgot'],
#  'forgot': ['things.'],
#  'things.': ['Had'],
#  'Had': ['your', 'you'],
#  'statement': ['be'],
#  'true,': ['her'],
#  'father': ['would’ve'],
#  'would’ve': ['thrashed', 'moments'],
#  'thrashed': ['me.'],
#  'me.': ['Or', 'Linkin', '', 'I', '@919944213734', 'I', '@919944213734'],
#  'Or': ['at'],
#  'least': ['her.'],
#  'her.': ['You’ll'],
#  'You’ll': ['grasp'],
#  'grasp': ['the'],
#  'calculations': ['once'],
#  'once': ['you'],
#  'married.': ['Fortunately'],
#  'Fortunately': ['it'],
#  'clicked': ['for'],
#  'first': ['attempt.', 'da.'],
#  'attempt.': ['Thank'],
#  'Thank': ['god'],
#  'god': ['now'],
#  'now': ['i', '-'],
#  'become': ['fan'],
#  'fan': ['of'],
#  'pun': ['intended'],
#  'intended': ['statements.'],
#  'statements.': ['nice.'],
#  'nice.': ['keep'],
#  'keep': ['them'],
#  'them': ['coming', 'in'],
#  'coming': ['Tempting'],
#  'Tempting': ['trap,'],
#  'trap,': ['wont'],
#  'wont': ['fall.'],
#  'fall.': ['kay'],
#  'kay': ['?', '?'],
#  'wait': ['for'],
#  '@919604854613': ['to', 'Read', '@919946628663', 'Genuinely', 'that'],
#  'wake': ['up.'],
#  'up.': ['he'],
#  'he': ['will', 'was', 'ly', 'is', 'be'],
#  'endorse': ['whiskey,'],
#  'whiskey,': ['ask'],
#  'us': ['to', 'a', 'I', 'used'],
#  'peace,': ['&'],
#  '&': ['tuck',
#   'the',
#   'find',
#   'move',
#   'avoid',
#   'looked',
#   'pushed',
#   'mingle.',
#   '@919944213734',
#   'me.'],
#  'tuck': ['into'],
#  'bed': ['again'],
#  'again': ['always'],
#  'always': ['been', 'grim.', 'Deepak,'],
#  'big': ['shot.'],
#  'shot.': ['not'],
#  'surprise.': ['I'],
#  'don’t': ['play', 'remember', 'tell', 'you', 'you', 'believe'],
#  'play': ['with'],
#  'fire,': ['Rambi'],
#  'Rambi': ['Deepak'],
#  'Deepak': ['can', 'is', 'isn’t'],
#  'accept': ['anyone'],
#  'anyone': ['tease', 'needs', 'fits'],
#  'tease': ['him,'],
#  'him,': ['not'],
#  'Krishna.': ['When'],
#  'When': ['did'],
#  'things': ['happen.'],
#  'happen.': ['I'],
#  'prolly': ['spent'],
#  'spent': ['all'],
#  '4': ['years'],
#  'sleeping': ['in'],
#  'bench.': ['Let’s'],
#  'Let’s': ['ask', 'dig', 'clear'],
#  'subject.': ['@919946628663'],
#  '@919946628663': ['Pathen', '@918056193719', 'name', '', 'slightly', ''],
#  'Pathen': ['sounds'],
#  'sounds': ['past'],
#  'past': ['&', '@919604854613'],
#  'tone': ['feels'],
#  'feels': ['he'],
#  'heartbroken': ['by', 'message'],
#  'What': ['has', 'was', 'happened', 'did', 'do'],
#  'happened': ['Bromance', 'da.'],
#  'Bromance': ['👯\u200d♂️'],
#  '👯\u200d♂️': ['May'],
#  'May': ['be'],
#  'Raj': ['believes', 'give', 'are'],
#  'believes': ['it'],
#  'wasn’t': ['in'],
#  'past.': ['Let’s', 'God'],
#  'dig': ['deep'],
#  'deep': ['&'],
#  'facts.': ['Good'],
#  'Good': ['job', 'night', 'evening'],
#  '@919789987036': ['I’m',
#   'Sounds',
#   'why',
#   '',
#   'Googled',
#   'class',
#   'threw',
#   '🤣'],
#  'I’m': ['focused', 'trying', 'still'],
#  'focused': ['at'],
#  'one': ['thing'],
#  'time.': ['Let’s', '@918056193719'],
#  'clear': ['out'],
#  'out': ['the'],
#  'doubts': ['we’ve'],
#  'we’ve': ['What'],
#  'reason': ['you'],
#  'were': ['heartbroken.'],
#  'heartbroken.': ['Tell'],
#  'Tell': ['us.'],
#  'us.': ['Raj', '😂'],
#  'give': ['us'],
#  'hint.': ['I’ll'],
#  'I’ll': ['try'],
#  'try': ['my'],
#  'best.': ['Focus'],
#  'Focus': ['on'],
#  'message': ['first'],
#  'Then': ['can'],
#  'take': ['up', 'this', 'average?'],
#  'riyas': ['rift'],
#  'rift': ['with'],
#  'Deepak.': ['What', 'Itlll'],
#  'that’s': ['something', 'it.'],
#  'push': ['people'],
#  'people': ['exit,'],
#  'exit,': ['we'],
#  'we': ['can', 'wouldn’t', 'met', 'can'],
#  'stop': ['&', 'looking'],
#  'move': ['on.', 'on'],
#  'We': ['din', 'can', 'can’t', 'don’t', 'should'],
#  'Talk': ['relevant'],
#  'relevant': ['stuff'],
#  'stuff': ['dude'],
#  'dude': ['Presuming'],
#  'Presuming': ['something'],
#  'gross': ['happened.'],
#  'happened.': ['Deepak'],
#  'crumbling.': ['We'],
#  'Sounds': ['sensitive'],
#  'sensitive': ['issue.'],
#  'issue.': ['Leave'],
#  'Leave': ['it'],
#  'dude.': ['😂', '🤷🏻\u200d♂️', 'Don’t', 'Learning', 'Prolly'],
#  'Today': ['truly'],
#  'belongs': ['to'],
#  'Raj.': ['Hands'],
#  'Hands': ['down.', 'down.'],
#  'down.': ['Stumping', ''],
#  'Stumping': ['Deepak'],
#  'isn’t': ['an'],
#  'easy': ['thing'],
#  'youngest': ['amongst'],
#  'amongst': ['us', 'us.'],
#  'think.': ['Ask'],
#  'Ask': ['Deepak.'],
#  'Itlll': ['be'],
#  'much': ['better'],
#  'better': ['Lie.', 'than'],
#  'Lie.': ['You’re'],
#  'You’re': ['bad', 'pushing'],
#  'bad': ['at'],
#  'pretence': ['@17164309669'],
#  '@17164309669': ['Table', 'cant'],
#  'Table': ['tennis'],
#  'tennis': ['?'],
#  '🤣': ['What', 'don’t', 'Where', '🤣', 'Full', '@919944213734'],
#  '🤷🏻\u200d♂️': ['I’m'],
#  'trying': ['to'],
#  'peace': ['&', 'prevail'],
#  'embarrassment': ['here'],
#  'here': ['WTF.', ''],
#  'WTF.': ['Raj'],
#  'dope': ['today?'],
#  'today?': ['We'],
#  'can’t': ['stand', 'forget', 'believe', 'do'],
#  'stand': ['you', 'both.'],
#  'bruh': ['You', '😜'],
#  'missed': ['Karthik'],
#  'Karthik': ['Kottiswaran', 'Cringe', 'is', 'is', 'is'],
#  'Kottiswaran': ['in'],
#  'list.': ['Deepak’s'],
#  'Deepak’s': ['right'],
#  'hand.': ['Did'],
#  'Did': ['I'],
#  'remember': ['da'],
#  'da': ['😂', 'Beautiful', 'next'],
#  'Neha.': ['Beautiful'],
#  'Beautiful': ['name', 'girl'],
#  'name': ['da', 'in', 'and'],
#  'girl': ['too,'],
#  'too,': ['but'],
#  'but': ['spoiled', 'i'],
#  'spoiled': ['by'],
#  'Cringe': ['worthy'],
#  'worthy': ['dude.'],
#  'Don’t': ['even', 'know'],
#  'talk': ['about'],
#  'about': ['it', '@919944213734'],
#  '🙏🏼': ['😂', 'NehaThik'],
#  'tied': ['knot'],
#  'knot': ['on'],
#  'Neha,': ['we'],
#  'wouldn’t': ['have'],
#  'raised': ['question'],
#  'too': ['small.'],
#  'small.': ['Stone'],
#  'Stone': ['cold'],
#  'cold': ['crooked'],
#  'crooked': ['heart'],
#  'heart': ['Karthik,'],
#  'Karthik,': ['you'],
#  'tissue': ['paper'],
#  'paper': ['da.'],
#  'At': ['final'],
#  'final': ['semester,'],
#  'semester,': ['she’s'],
#  'she’s': ['got', 'not.', 'been'],
#  'got': ['pimples', 'a', 'it'],
#  'pimples': ['&'],
#  'looked': ['like'],
#  'whore.': ['But'],
#  'not.': ['Every'],
#  'Every': ['time'],
#  'time': ['I', 'due', 'its'],
#  'her,': ['it'],
#  'felt': ['like'],
#  'sprayed': ['with'],
#  'semen': ['at'],
#  'mug.': ['We'],
#  'tell': ['this'],
#  'wife.': ['No'],
#  'worries': ['Whatsoever.'],
#  'Whatsoever.': ['I'],
#  'pretty': ['women.'],
#  'women.': ['😂'],
#  'True': ['I’ve', '\u200eimage'],
#  'I’ve': ['realised'],
#  'realised': ['it'],
#  'chortled': ['at'],
#  'Linkin': ['park,'],
#  'park,': ['iPod,'],
#  'iPod,': ['power'],
#  'power': ['shut'],
#  'down,': ['Slept'],
#  'Slept': ['a'],
#  'kya,': ['can’t'],
#  'forget': ['all'],
#  'Macha.': ['I'],
#  'next': ['to', 'DPK-PJK', 'visit'],
#  'Merely': ['dude.'],
#  'Learning': ['English.'],
#  'English.': ['By'],
#  'By': ['any'],
#  'chance,': ['does'],
#  'does': ['your'],
#  'wife': ['know'],
#  'Read': ['sex'],
#  'sex': ['books'],
#  'books': ['eh.'],
#  'eh.': ['Fucker'],
#  'Fucker': ['you'],
#  'guys': ['fooled'],
#  'fooled': ['me'],
#  'pushed': ['me'],
#  'read': ['it', 'No', 'someday.'],
#  'aloud.': ['Omg'],
#  'Omg': ['I'],
#  'think': ['I', "he's", 'anyone', 'i'],
#  'must': ['stop', 'be'],
#  'This': ['is', 'time'],
#  '': ['I',
#   '',
#   'Amen',
#   'consider',
#   '@917338813130',
#   '--',
#   'Easy-peasy',
#   'Who',
#   'Who',
#   'Hands',
#   'Who',
#   'Who',
#   'Who',
#   'Who',
#   'Whose',
#   'Who',
#   'Who',
#   'is',
#   '@918056193719',
#   'everybody',
#   'can’t'],
#  'practice': ['only'],
#  'starting': ['point.'],
#  'point.': ['Good'],
#  'night': ['folks.'],
#  'folks.': ['Heading', 'He’s'],
#  'Heading': ['toward'],
#  'toward': ['a'],
#  'disaster.': ['I'],
#  'longer': ['want'],
#  'involved.': ['🙏🏼'],
#  'NehaThik': ['I'],
#  'kid': ['da.'],
#  'Embarrassing': ['to'],
#  'hear': ['my'],
#  'God': ['🤣'],
#  'lock': ['your'],
#  'phone': ['?', 'Nope.'],
#  'Set': ['a'],
#  'passcode,': ['Face'],
#  'Face': ['ID.'],
#  'ID.': ['What'],
#  'mean.': ['\u200eYou'],
#  '\u200eYou': ['deleted'],
#  'deleted': ['this'],
#  'message.': ['Yeah.', 'He'],
#  'Yeah.': ['Still'],
#  'Still': ['he’s'],
#  'he’s': ['my'],
#  'son.': ['You’re'],
#  'pushing': ['him.'],
#  'him.': ['I'],
#  'lighter': ['note'],
#  'note': ['Let'],
#  'Let': ['this'],
#  'prevail': ['forever'],
#  'forever': ['♾'],
#  '♾': ['here'],
#  'Amen': ['Time'],
#  'Time': ['will'],
#  'heal': ['you'],
#  'Invite': ['him'],
#  'him': ['to', 'comfortable.'],
#  'home.': ['Make'],
#  'Make': ['him'],
#  'comfortable.': ['You'],
#  'both': ['are'],
#  'single.': ['Glance', '@917338813130'],
#  'Glance': ['at'],
#  'his': ['“mine”', 'model'],
#  '“mine”': ['folder'],
#  'folder': ['&'],
#  'mingle.': ['@919789987036'],
#  'involved': ['in'],
#  'church': ['services', 'services', 'services?'],
#  'services': ['Gross', 'its'],
#  'Gross': ['@919789987036'],
#  'consider': ['church'],
#  'whats': ['wrong', 'mia'],
#  'wrong': ['with'],
#  'services?': ['Become'],
#  'Become': ['trance'],
#  'trance': ['Fahad.'],
#  'Fahad.': ['Chick'],
#  'Chick': ['magnets'],
#  'magnets': ['?'],
#  'evening': ['ji'],
#  'ji': ['@919840648198'],
#  '@919840648198': ['😂', '@17164309669', '@919604854613'],
#  'Look': ['at'],
#  "Selva's": ['profile'],
#  'profile': ['pic,'],
#  'pic,': ['and'],
#  'photo': ['How'],
#  'model': ['story?'],
#  'story?': ['Ok'],
#  'cool.': ['Karthik'],
#  'typing...': ['erasing..', 'erasing...', 'erasing...'],
#  'erasing..': ['Karthik'],
#  'erasing...': ['Karthik', 'Porn'],
#  'Porn': ['uh'],
#  'uh': ['😆'],
#  '😆': ['🤣', 'Hahaha', 'Except'],
#  'Where': ['is'],
#  '@918056193719': ['', '', ''],
#  '@917338813130': ['Never', 'is'],
#  'Never': ['heard'],
#  'heard': ['them', 'from'],
#  'times.': ['whats'],
#  'mia': ['I'],
#  'creepy': ['@919789987036'],
#  'Googled': ['supposed'],
#  'supposed': ['to'],
#  'paranormal': ['activity.'],
#  'activity.': ['typo'],
#  'typo': ['I'],
#  "he's": ['lying.'],
#  'lying.': ['He'],
#  'He': ['must', 'wouldnt', 'would', 'means', 'finds'],
#  'preparing': ['for'],
#  '5th': ['Azure'],
#  'Azure': ['certification.'],
#  'certification.': ['Wanted'],
#  'Wanted': ['to'],
#  'spin': ['since'],
#  'since': ['release,'],
#  'release,': ['waited'],
#  'waited': ['for'],
#  'iTunes': ['india'],
#  'india': ['release.'],
#  'release.': ['Din'],
#  'happen,': ['lost'],
#  'lost': ['patience,'],
#  'patience,': ['and'],
#  'pirated': ['copy'],
#  'copy': ['today.'],
#  'today.': ['Have'],
#  'someday.': ['anyone'],
#  'needs': ['a'],
#  'copy,': ['ping'],
#  'ping': ['me.'],
#  'https://m.economictimes.com/news/politics-and-nation/muslim-refugees-become-christians-to-take-caa-benefit/articleshow/77117484.cms': ['https://t.co/yjmKYeFCpL'],
#  'https://t.co/yjmKYeFCpL': ['He'],
#  'wouldnt': ['have'],
#  'watched': ['it'],
#  'Hahaha': ['hard', 'True'],
#  'hard': ['labour'],
#  'labour': ['mate.'],
#  'mate.': ['Not'],
#  'thing.': ['Hmmm'],
#  'dithering': ['for'],
#  'long..': ['fucking'],
#  'fucking': ['karthik.'],
#  'karthik.': ['type'],
#  'type': ['and', 'and'],
#  'erase..': ['type', 'my'],
#  'arse': ['hahaha..'],
#  'hahaha..': ['i'],
#  'texting': ['from'],
#  'mac': ['bruh.', '\u200eimage'],
#  'bruh.': ['whatsapp', 'not'],
#  'whatsapp': ['interface'],
#  'interface': ['is'],
#  'Mac': ['bruh.'],
#  'Nope.': ['you'],
#  'it.': ['you', 'Really', 'Shambles'],
#  'troll': ['but'],
#  'compliment.': ['besides,'],
#  'besides,': ['just'],
#  'just': ['placed'],
#  'placed': ['an'],
#  'order': ['for'],
#  'iPhone': ['SE.'],
#  'SE.': ['Long'],
#  'Long': ['time'],
#  'due': ['for'],
#  'shanthini.': ['This'],
#  'enforced.': ['Who'],
#  'Who': ['is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is'],
#  'playboy': ['--'],
#  '--': ['remove', 'Riyas'],
#  'remove': ['my'],
#  'name.': ['replace'],
#  'replace': ['it'],
#  'yours.': ['include'],
#  'include': ['your'],
#  'many': ['of'],
#  'options': ['da.'],
#  'lazy': ['ass'],
#  'ass': [''],
#  'Riyas': ['Khan.', 'or'],
#  'Khan.': ['Without'],
#  'Without': ['a'],
#  'doubt.': ['Always'],
#  'Always': ['he'],
#  'ly': ['down'],
#  'bed.': ['Who'],
#  'Masturbation': ['king:'],
#  'king:': ['', '@919840648198'],
#  'Easy-peasy': ['@919677200872'],
#  '@919677200872': ['', 'I'],
#  'mooda': ['kudi:'],
#  'kudi:': ['Funny'],
#  'Funny': ['that'],
#  '😂😂😂': ['other'],
#  'other': ['3', 'two'],
#  'equal': ['in'],
#  'view.': [''],
#  'playboy:': ['@919604854613'],
#  'psycho:': ['i'],
#  'fits': ['in.'],
#  'in.': [''],
#  'Kalaikum': ['king:'],
#  'both.': [''],
#  'best': ['organiser:', 'oolu', 'photographer:'],
#  'organiser:': ['I'],
#  '@919944213734': ['can', 'is', '?', '', 'is', 'Both', 'is'],
#  'others.': [''],
#  'idea': ['mani'],
#  'mani': ['('],
#  '(': ['technical'],
#  'technical': [')'],
#  ')': [':'],
#  ':': ['Remove'],
#  'Remove': ['me,'],
#  'me,': ['Add', '@919944213734'],
#  'Add': ['@919663655116'],
#  "He's": ['the'],
#  '1st': ['Geek'],
#  'Geek': ['we'],
#  'met': ['in'],
#  'our': ['college.'],
#  'college.': ['Everyone'],
#  'Everyone': ['would'],
#  'agree.': [''],
#  'Whose': ['combo'],
#  'combo': ['is'],
#  'very': ['strong:'],
#  'strong:': ['@919840648198'],
#  'Genuinely': ['tight'],
#  'tight': ['knit'],
#  'knit': ['group,'],
#  'group,': ['next'],
#  'DPK-PJK': ['equally'],
#  'equally': ['strong.'],
#  'strong.': [''],
#  'oolu': ['othing'],
#  'othing': ['(liar'],
#  '(liar': ['):'],
#  '):': ['Perhaps'],
#  'Perhaps': ['@919677200872'],
#  'two': ['names'],
#  'names': ['are'],
#  'there.': [''],
#  'photographer:': ['@919946628663'],
#  'slightly': ['ahead', 'ahead', 'ahead'],
#  'ahead': ['of', 'of', 'in'],
#  'doing': ['ok.'],
#  'ok.': ['I'],
#  'am': ['in'],
#  'between.': ['No'],
#  'No.': ['@919946628663'],
#  'improved.': ['On'],
#  'On': ['photography'],
#  'photography': ['?'],
#  'evaluate': ['only'],
#  'same': ['playground.'],
#  'playground.': ['3'],
#  'used': ['iPhones,', 'DSLR'],
#  'iPhones,': ['and'],
#  'shot': ['photos.', 'on', 'on'],
#  'photos.': ['Remember'],
#  'Remember': ['most'],
#  'most': ['of'],
#  'class': ['marketing'],
#  'marketing': ['photos'],
#  'photos': ['are', 'shot'],
#  'iPhone,': ['by'],
#  'MEEEEEEEEEEE,': ['kay'],
#  'agree': ['that', 'that'],
#  'par': ['with'],
#  'photographic': ['sense'],
#  'yet.': ['Isnt'],
#  'Isnt': ['it'],
#  'pangu': ['@919944213734'],
#  'pose.': ['How'],
#  'average?': ['Neither'],
#  'Neither': ['Riyas'],
#  'DSLR': ['cam'],
#  'cam': ['in'],
#  'terms': ['of', 'of'],
#  'iPhones.': ['WTF'],
#  'WTF': ['Repulsive'],
#  'Repulsive': ['fuckkkk'],
#  'fuckkkk': ['you'],
#  '🤣🤣🤣🤣🤣': ['I'],
#  'bet': ["you'd"],
#  "you'd": ['be'],
#  'number': ['1'],
#  '1': ['amongst'],
#  'It’s': ['okay.', 'always'],
#  'okay.': ['I'],
#  'you’re': ['slightly'],
#  'macro': ['photography.'],
#  'photography.': ['Dai'],
#  'Dai': ['😂', 'pub'],
#  'believe': ['it.', 'that.'],
#  'Really': ['?'],
#  'threw': ['up'],
#  'lot,': ['and'],
#  'Shambles': ['@919789987036'],
#  'Full': ['of'],
#  'pretence.': ['Ignored'],
#  'Ignored': ['Drunkard'],
#  'Drunkard': ['raj'],
#  'raj': ['as'],
#  'found': ['was'],
#  'grim.': ['Don’t'],
#  'thinking.': ['I'],
#  'P': ['in'],
#  '“palasu”': ['takes'],
#  'takes': ['me'],
#  'back': ['to'],
#  'Rambavi': ['times'],
#  'times': ['bruh'],
#  '😜': ['Sanatorium'],
#  'Sanatorium': ['folks,'],
#  'folks,': ['got'],
#  '👏🏼': ['\u200esticker'],
#  'pub': ['da'],
#  'visit': ['would’ve'],
#  'moments': ['of'],
#  'nuptial': ['dude.'],
#  'Prolly': ['😆'],
#  'Except': ['me,'],
#  'everybody': ['drinks.'],
#  'drinks.': ['😂'],
#  'should': ['let'],
#  'let': ['others'],
#  'others': ['engage'],
#  'engage': ['da.'],
#  'Deepak,': ['Rambi,'],
#  'Rambi,': ['Raj,'],
#  'Raj,': ['Krishna,'],
#  'Krishna,': ['&'],
#  'forced': ['bachelor.'],
#  'bachelor.': ['@919663655116'],
#  'busy': ['all'],
#  'Pipe': ['down'],
#  'means': ['about'],
#  'Both': ['Yeah'],
#  'Yeah': ['Macha'],
#  '😏': ['Hmm'],
#  'Hmm': ['🤣'],
#  'telling': ['you'],
#  'finds': ['me'],
#  'good': ['friend.'],
#  'friend.': ['Not'],
#  'He’s': ['ashamed'],
#  'ashamed': ['of'],
#  'all.': ['Ok'],
#  'gonna': ['hit'],
#  'hit': ['the'],
#  'sack.': ['']}
